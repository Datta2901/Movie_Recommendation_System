# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
#to the request the url form library and read it
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
tables
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th colspan="2" style="width:6%">Opening
#  </th>
#  <th style="width:18%">Title
#  </th>
#  <th style="width:18%">Production company
#  </th>
#  <th>Cast and crew
#  </th>
#  <th style="width:4%;"><style data-mw-deduplicate="TemplateStyles:r1038841319">.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}</style><span class="rt-commentedText tooltip tooltip-dotted" title="References">Ref.</span>
#  </th></tr>
#  <tr>
#  <th rowspan="17" style="text-align:center; background:#f7bf87">J<br/>A<br/>N<br/>U<br/>A<br/>R<br/>Y
#  </th>
#  <td style="text-align:center; background:#f7dfc7"><b>3</b>
#  </td>
#  <td><i><a href="/wiki/The_Grudge_(2020_film)" title="The Grudge (2020 film)">The Grudge</a></i></td>
# ...

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ...

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [274 rows x 2 columns]

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '06a1b4618e615a37a206a55e35c27514'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
        
        return np.NaN
    else:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/550?api_key=06a1b4618e615a37a206a55e35c27514'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        if data_json['genres']:
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                
                genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-16-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     genres
# 0    Drama
# ...

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-19-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-21-42c5f763f942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-23-ca9c918a7840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title
# 0           John Cho  Drama             The Grudge
# 1    Jessica Henwick  Drama             Underwater
# ...

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     27
# genres            1
# movie_title       0
# comb             28
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-34-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 268       Pete Docter             Jamie Foxx           Tina Fey
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title  \
# 0           John Cho  Drama             the grudge
# 1    Jessica Henwick  Drama             underwater
# ...

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5864           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5865             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5866  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5867        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5868           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6110        Pete Docter             Jamie Foxx          Tina Fey
# 6111   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6112        Regina King      Kingsley Ben-Adir         Eli Goree
# 6113    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6114   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
#final_df.to_csv('main_data.csv',index=False)

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source2021 = urllib.request.urlopen(link).read()
soup2021  =  bs.BeautifulSoup(source2021,'lxml')
source2021
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of American films of 2021 - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a8e01bb8-65a9-4929-95ea-7ba81f7dcf7f","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_American_films_of_2021","wgTitle":"List of American films of 2021","wgCurRevisionId":1081760434,"wgRevisionId":1081760434,"wgArticleId":58150649,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: url-status","Articles with short description","Short description is different fro
# ...

# %%
soup2021
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of American films of 2021 - Wikipedia</title>
# ...

# %%
tables2021 = soup2021.find_all('table',class_='wikitable sortable')

# %%
tables2021
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th colspan="2" style="width:6%">Opening
#  </th>
#  <th style="width:18%">Title
#  </th>
#  <th style="width:18%">Production company
#  </th>
#  <th>Cast and crew
#  </th>
#  <th style="width:4%;"><style data-mw-deduplicate="TemplateStyles:r1038841319">.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}</style><span class="rt-commentedText tooltip tooltip-dotted" title="References">Ref.</span>
#  </th></tr>
#  <tr>
#  <th rowspan="19" style="text-align:center; background:#f7bf87; text color:#000;">J<br/>A<br/>N<br/>U<br/>A<br/>R<br/>Y
#  </th>
#  <td rowspan="1" style="text-align:center; background:#f7dfc7"><b>1</b>
#  </td>
#  <td><i><a href="/wiki/Shadow_in_the_Cloud" title="Shadow in the Cloud">Shadow in the Cloud</a></i></td>
#  <td><a href="/wiki/Vertical_Entertainment" title="Vertical Entertainment">Vertical Entertainment</a></td>
# ...

# %%
df1 = pd.read_html(str(tables2021[0]))[0]
df2 = pd.read_html(str(tables2021[1]))[0]
df3 = pd.read_html(str(tables2021[2]))[0]
df4 = pd.read_html(str(tables2021[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1 = df1.append(df2)
df1 = df1.append(df3)
df1 = df1.append(df4)

# %%
df1
# Out:
#      Opening  Opening.1                   Title  \
# 0    JANUARY        1.0     Shadow in the Cloud
# 1    JANUARY       13.0         The White Tiger
# 2    JANUARY       14.0             Locked Down
# 3    JANUARY       15.0                 The Dig
# 4    JANUARY       15.0        Outside the Wire
# ..       ...        ...                     ...
# 90  DECEMBER       25.0  The Tragedy of Macbeth
# 91  DECEMBER       25.0    A Journal for Jordan
# 92  DECEMBER       25.0       American Underdog
# 93  DECEMBER       26.0                 Memoria
# 94  DECEMBER        NaN                     NaN
#
#                                    Production company  \
# 0                              Vertical Entertainment
# 1                                             Netflix
# 2                     HBO Max / Warner Bros. Pictures
# 3                         Netflix / Clerkenwell Films
# 4                                             Netflix
# ..                                                ...
# ...

# %%
df_2021 = df1[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                      Title                                      Cast and crew
# 0      Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1          The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2              Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                  The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4         Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                     ...                                                ...
# 90  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 91    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 92       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 93                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 94                     NaN                                                NaN
#
# [358 rows x 2 columns]

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-51-252c1cda1e49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-52-d9d8ec523bdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-52-d9d8ec523bdb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-53-597eaf6de001>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                      Title                                      Cast and crew  \
# 0      Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1          The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2              Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                  The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4         Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                     ...                                                ...
# 90  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 91    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 92       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 93                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 94                     NaN                                                NaN
#
# ...

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
#new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
#df=pd.DataFrame(['product a','product b','product c', 'product d'],index=['a','b','c','d'])

# %%
df_2021
# Out:
#                movie_title                                      Cast and crew  \
# 0      Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1          The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2              Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                  The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4         Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                     ...                                                ...
# 90  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 91    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 92       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 93                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 94                     NaN                                                NaN
#
# ...

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                         director_name  \
# 0                                      Roseanne Liang
# 1                                       Ramin Bahrani
# 2                                          Doug Liman
# 3                                         Simon Stone
# 4                                     Mikael Håfström
# ..                                                ...
# 90                                          Joel Coen
# 91                                  Denzel Washington
# 92                                     Erwin brothers
# 93  Apichatpong Weerasethakul (director/acreenplay...
# 94                                                nan
#
#                                          actor_1_name       actor_2_name  \
# 0                                  Chloë Grace Moretz  Taylor John Smith
# 1                                       Adarsh Gourav      Rajkummar Rao
# 2                                       Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']
new_df21.isna().sum()
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
new_df21 = new_df21.dropna(how='any')

# %%
old_df = pd.read_csv('final_data.csv')
final_df = final_df.append(new_df21,ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6442                                     Matthew Vaughn
# 6443                                          Joel Coen
# 6444                                  Denzel Washington
# 6445                                     Erwin brothers
# 6446  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# ...

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"

# %%
source2022 = urllib.request.urlopen(link).read()
soup2022  =  bs.BeautifulSoup(source2022,'lxml')

# %%
tables2022 = soup2022.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables2022[0]))[0]
df2 = pd.read_html(str(tables2022[1]))[0]
df3 = pd.read_html(str(tables2022[2]))[0]
df4 = pd.read_html(str(tables2022[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1 = df1.append(df2)
df1 = df1.append(df3)
df1 = df1.append(df4)

# %%
df1
# Out:
#      Opening  Opening.1                              Title  \
# 0    JANUARY        7.0                            The 355
# 1    JANUARY        7.0           The Legend of La Llorona
# 2    JANUARY        7.0                       The Commando
# 3    JANUARY       14.0                             Scream
# 4    JANUARY       14.0  Hotel Transylvania: Transformania
# ..       ...        ...                                ...
# 20  DECEMBER       16.0           Shazam! Fury of the Gods
# 21  DECEMBER       21.0                Untitled Mario film
# 22  DECEMBER       21.0        I Wanna Dance with Somebody
# 23  DECEMBER       25.0                            Babylon
# 24  DECEMBER       25.0                  A Man Called Otto
#
#                                    Production company  \
# 0   Universal Pictures / Freckle Films / FilmNatio...
# 1                                         Saban Films
# 2                                         Saban Films
# ...

# %%
df_2022 = df1[['Title','Cast and crew']]

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-71-4e8e2d4797da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(str(x)))
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-72-c257d850805a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-72-c257d850805a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# <ipython-input-72-c257d850805a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2022
# Out:
#                                 Title  \
# 0                             The 355
# 1            The Legend of La Llorona
# 2                        The Commando
# 3                              Scream
# 4   Hotel Transylvania: Transformania
# ..                                ...
# 20           Shazam! Fury of the Gods
# 21                Untitled Mario film
# 22        I Wanna Dance with Somebody
# 23                            Babylon
# 24                  A Man Called Otto
#
#                                         Cast and crew genres  \
# 0   Simon Kinberg (director/screenplay); Theresa R...  Drama
# 1   Patricia Harris Seeley (director/screenplay); ...  Drama
# 2   Asif Akbar (director); Koji Steven Sakai (scre...  Drama
# 3   Matt Bettinelli-Olpin, Tyler Gillett (director...  Drama
# 4   Jennifer Kluska, Derek Drymon (directors); Amo...  Drama
# ..                                                ...    ...
# 20  David F. Sandberg (director); Henry Gayden, Ch...  Drama
# ...

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
df_2022
# Out:
#                           movie_title  \
# 0                             The 355
# 1            The Legend of La Llorona
# 2                        The Commando
# 3                              Scream
# 4   Hotel Transylvania: Transformania
# ..                                ...
# 20           Shazam! Fury of the Gods
# 21                Untitled Mario film
# 22        I Wanna Dance with Somebody
# 23                            Babylon
# 24                  A Man Called Otto
#
#                                         Cast and crew genres  \
# 0   Simon Kinberg (director/screenplay); Theresa R...  Drama
# 1   Patricia Harris Seeley (director/screenplay); ...  Drama
# 2   Asif Akbar (director); Koji Steven Sakai (scre...  Drama
# 3   Matt Bettinelli-Olpin, Tyler Gillett (director...  Drama
# 4   Jennifer Kluska, Derek Drymon (directors); Amo...  Drama
# ..                                                ...    ...
# 20  David F. Sandberg (director); Henry Gayden, Ch...  Drama
# ...

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22
# Out:
#                            director_name      actor_1_name       actor_2_name  \
# 0                          Simon Kinberg  Jessica Chastain     Lupita Nyong'o
# 1                 Patricia Harris Seeley     Autumn Reeser       Antonio Cupo
# 2                             Asif Akbar     Mickey Rourke  Michael Jai White
# 3   Matt Bettinelli-Olpin, Tyler Gillett   Melissa Barrera      Mason Gooding
# 4          Jennifer Kluska, Derek Drymon      Andy Samberg       Selena Gomez
# ..                                   ...               ...                ...
# 20                     David F. Sandberg      Zachary Levi        Asher Angel
# 21        Aaron Horvath, Michael Jelenic       Chris Pratt    Anya Taylor-Joy
# 22                          Kasi Lemmons       Naomi Ackie     Ashton Sanders
# 23                       Damien Chazelle         Brad Pitt      Margot Robbie
# 24                          Marc Forster         Tom Hanks                NaN
#
# ...

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']
new_df22.isna().sum()
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
new_df22 = new_df22.dropna(how='any')

# %%
final_df = final_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6590      Tommy Wirkola    David Harbour    John Leguizamo
# 6591      James Cameron  Sam Worthington       Zoe Saldana
# 6592  David F. Sandberg     Zachary Levi       Asher Angel
# 6593       Kasi Lemmons      Naomi Ackie    Ashton Sanders
# 6594    Damien Chazelle        Brad Pitt     Margot Robbie
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
final_df.to_csv('main_data.csv',index=False)

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 268       Pete Docter             Jamie Foxx           Tina Fey
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name genres            movie_title  \
# 0           John Cho  Drama             the grudge
# 1    Jessica Henwick  Drama             underwater
# ...

# %%
new_df21
# Out:
#                                         director_name  \
# 0                                      Roseanne Liang
# 1                                       Ramin Bahrani
# 2                                          Doug Liman
# 3                                         Simon Stone
# 4                                     Mikael Håfström
# ..                                                ...
# 89                                     Matthew Vaughn
# 90                                          Joel Coen
# 91                                  Denzel Washington
# 92                                     Erwin brothers
# 93  Apichatpong Weerasethakul (director/acreenplay...
#
#                                          actor_1_name       actor_2_name  \
# 0                                  Chloë Grace Moretz  Taylor John Smith
# 1                                       Adarsh Gourav      Rajkummar Rao
# 2                                       Anne Hathaway   Chiwetel Ejiofor
# ...

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6590      Tommy Wirkola    David Harbour    John Leguizamo
# 6591      James Cameron  Sam Worthington       Zoe Saldana
# 6592  David F. Sandberg     Zachary Levi       Asher Angel
# 6593       Kasi Lemmons      Naomi Ackie    Ashton Sanders
# 6594    Damien Chazelle        Brad Pitt     Margot Robbie
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6595 entries, 0 to 6594
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  6595 non-null   object
#  1   actor_1_name   6595 non-null   object
#  2   actor_2_name   6595 non-null   object
#  3   actor_3_name   6595 non-null   object
#  4   genres         6595 non-null   object
#  5   movie_title    6595 non-null   object
#  6   comb           6595 non-null   object
# dtypes: object(7)
# memory usage: 360.8+ KB
